# %% [markdown]
# # Exploratory Data Analysis (EDA)
# First contact with the data obtain by https://www.kaggle.com/datasets/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis?resource=download

# %%
# TODO: -Git, chech order zipcode

# %% [markdown]
# ## DataCoSupplyChainDataset

# %%
import pandas as pd
df = pd.read_csv("data/raw_data/DataCoSupplyChainDataset.csv", encoding='latin-1')

# %% [markdown]
# ## Handle missing values
# - Product Description has no values (delete)
# - Order Zipcode has few values (might be able to calculate from lat lon)
# - Customer mail has no values (delete)
# - Product Status values check (delete)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  str
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  str
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  str
#  9   Customer City                  180519 non-null  str
#  10  Customer Country               180519 non-null  str
#  11  Customer Email                 180519 non-null  str
# ...

# %% [markdown]
# ### Check Product Status values

# %%
df['Product Status'].value_counts()
# Out:
# Product Status
# 0    180519
# Name: count, dtype: int64

# %% [markdown]
# They are all 0, for this reason it would also be eliminated

# %% [markdown]
# ### Delete useless columns
# - Product Description
# - Customer mail
# - Product Status

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df.drop(columns=['Product Description', 'Customer Email', 'Product Status'], inplace=True)

# %% [markdown]
# ### Check Order Zipcode values
